# %%
pelicula1 = {
    "nombre": "Titanic", 
    "genero": "Drama", 
    "minutos": 120,
    "inventario": 0
}
pelicula2 = {
    "nombre": "Star Trek", 
    "genero": "Ficcion", 
    "minutos": 120,
    "inventario": 0,
    "formato": "digital"
}
pelicula3={}

lista = [pelicula1, pelicula2, pelicula3]

# %%
class Pelicula:
    ## como se inicia
    ## metodos: init  especifiar como tienen que ser la pelicula
    def __init__(self, nombre, genero, minutos, inventario=0, idioma="Español"):
        ## lo que tiene que tener la pelicula: atributos
        self.nombre = nombre
        self.genero= genero
        self.minutos=minutos
        self.inventario=inventario
        self.idioma = idioma
        self.fomato = "Digital"
    
    ## ver los detalles de la pelicula: metodos--- acciones
    def mostrar_pelicula(self):
        print(f" Pelicula: {self.nombre} Genero: {self.genero} Minutos: {self.minutos}  ")

    ## actualizar invetario
    ## actualizar_inventario(pelicula5, adios)
    def actualizar_inventario(self, hola): ## coge el numero a actualizar 
        self.inventario = hola ## lo pone en el inventario
        print(f" Tu inventario se ha actualizado {self.inventario}")


pelicula4 = Pelicula("Avatar", "Accion", 150, 5 )
pelicula5 = Pelicula("Barbie", "Comedia", 120, 0)

# %%
# adios = input("Dime la cantidad") # aqui lo pone el usuario
pelicula5.actualizar_inventario(10) # aqui le digo a la pelicual que tiene actualizar = parametros
# Out:
#  Tu inventario se ha actualizado 10

# %%
pelicula5.inventario
# Out:
# 10

# %%
pelicula1
# Out:
# {'nombre': 'Titanic', 'genero': 'Drama', 'minutos': 120, 'inventario': 0}

# %%
pelicula4.mostrar_pelicula()
# Out:
#  Pelicula: Avatar Genero: Accion Minutos: 150

# %%
nombre = "Angeles"

# %% [markdown]
# Vamos a crear la clase Adalaber.
# Toda Adalaber tiene los siguientes atributos: nombre, apellido, superpoder, frase que más repite y una mascota, aunque por defecto puede tener "ninguna".
# Toda Adalaber puede: saludar a alguien, decir su propio nombre y apellido, decir cuál es su mascota (si tiene), decir su frase, decir su superpoder y decir la tabla de multiplicar del numero que le pasemos (somos muy listas :aliviado:)
# Cada una podrá crearse un objeto que rellenar con sus datos, es decir, podrá crear un objeto de ella misma. Y así demostrar que puede hacer lo que toda Adalaber!

# %%
class Adalaber:
    def __init__(self, nombre, apellido, superpoder, frase, mascota="ninguna"):
        self.nombre = nombre
        self.apellido = apellido
        self.superpoder = superpoder
        self.frase = frase
        self.mascota = mascota
    def saludar(self):
        print(f"Hola, me llamo {self.nombre} {self.apellido}")
    def decir_mascota(self):
        if self.mascota != "ninguna":
            print(f"Mi mascota es {self.mascota}")

# %%
adalaberYanelis = Adalaber("Yanelis", "Serrano", "Saber que piensan mis alumnas", "Depende")

# %%
adalaberYanelis.saludar()
# Out:
# Hola, me llamo Yanelis Serrano

# %%
adalaberYanelis.decir_mascota()

# %%
adalaberYanelis.frase
# Out:
# 'Depende'
